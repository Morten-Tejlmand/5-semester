# %%
from statsbombpy import sb
import pandas as pd
import numpy as np

# %%
#find ids for bayer matches
matches = sb.matches(competition_id=9, season_id=281)
match_ids = matches['match_id'].values.tolist()

events = sb.competition_events(
    country="Germany",
    division= "1. Bundesliga",
    season="2023/2024",
    gender="male"
)
events = events[events['match_id'].isin(match_ids)]
df = events[events["team"]=="Bayer Leverkusen"]
# Out:
# c:\Users\nikka\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# c:\Users\nikka\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
MATCH_ID = np.int64(3895302)
match = events[events["match_id"] == MATCH_ID]

# %%
match.head()
# Out:
#    50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0    NaN                NaN                  NaN                     NaN
# 1    NaN                NaN                  NaN                     NaN
# 68   NaN                NaN                  NaN                     NaN
# 69   NaN                NaN                  NaN                     NaN
# 70   NaN                NaN                  NaN                     NaN
#
#    ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                             NaN              NaN             NaN
# 1                             NaN              NaN             NaN
# 68                            NaN              NaN             NaN
# 69                            NaN              NaN             NaN
# 70                            NaN              NaN             NaN
#
#    block_save_block carry_end_location clearance_aerial_won  ...  \
# ...

# %%
xT = pd.read_csv("https://raw.githubusercontent.com/AKapich/WorldCup_App/main/app/xT_Grid.csv", header=None)
xT = np.array(xT)
xT_rows, xT_cols = xT.shape

# %%
coords = match[["team", "location", "pass_end_location", "carry_end_location", "timestamp", "type", "shot_type", "shot_statsbomb_xg"]]

# %%
coords_sorted = coords.sort_values("timestamp")

# %%
coords_sorted[" "].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Substitution', 'Pass',
#        'Ball Receipt*', 'Carry', 'Pressure', 'Duel', 'Dispossessed',
#        'Block', 'Bad Behaviour', 'Miscontrol', 'Ball Recovery', 'Dribble',
#        'Interception', 'Foul Committed', 'Foul Won', 'Shot',
#        'Goal Keeper', 'Clearance', 'Error', 'Injury Stoppage',
#        'Referee Ball-Drop', '50/50', 'Offside', 'Dribbled Past',
#        'Tactical Shift', 'Shield', 'Player Off', 'Player On', 'Half End'],
#       dtype=object)

# %%
coords_sorted[coords_sorted["type"] == "Shot"]
# Out:
#                     team       location pass_end_location carry_end_location  \
# 132932     Werder Bremen   [97.5, 40.8]               NaN                NaN
# 132917     Werder Bremen  [100.4, 35.1]               NaN                NaN
# 132918  Bayer Leverkusen  [114.6, 33.5]               NaN                NaN
# 132919     Werder Bremen  [106.2, 55.8]               NaN                NaN
# 132933  Bayer Leverkusen   [93.8, 34.8]               NaN                NaN
# 132920  Bayer Leverkusen  [113.9, 47.4]               NaN                NaN
# 132934  Bayer Leverkusen   [93.0, 39.1]               NaN                NaN
# 132921  Bayer Leverkusen   [89.2, 42.5]               NaN                NaN
# 132922  Bayer Leverkusen  [110.2, 32.6]               NaN                NaN
# 132923     Werder Bremen  [105.4, 45.1]               NaN                NaN
# 132935  Bayer Leverkusen  [106.3, 29.6]               NaN                NaN
# ...

# %%
events_sorted = events.sort_values("timestamp"); events_sorted = events_sorted[events_sorted["match_id"] == MATCH_ID]

# %%
events_sorted
# Out:
#        50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0        NaN                NaN                  NaN                     NaN
# 137248   NaN                NaN                  NaN                     NaN
# 1        NaN                NaN                  NaN                     NaN
# 68       NaN                NaN                  NaN                     NaN
# 69       NaN                NaN                  NaN                     NaN
# ...      ...                ...                  ...                     ...
# 40057    NaN                NaN                  NaN                     NaN
# 78216    NaN                NaN                  NaN                     NaN
# 851      NaN                NaN                  NaN                     NaN
# 137112   NaN                NaN                  NaN                     NaN
# 137113   NaN                NaN                  NaN                     NaN
#
# ...
