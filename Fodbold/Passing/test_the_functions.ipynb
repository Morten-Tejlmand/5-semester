# %%
from statsbombpy import sb
import pandas as pd
from helper_functions import(match_ids,
                             create_graphs,
                             create_graphs_dict,
                             plot_graphs)

# %%
#All events sorted for barca home games and possession 
events = sb.competition_events(
    country="Germany",
    division= "1. Bundesliga",
    season="2023/2024",
    gender="male"
)
# Out:
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/morten/anaconda3/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df = match_ids(events, "Bayer Leverkusen", season_id=281, competition_id=9)
possesion, final_sequence = create_graphs(df)
# Out:
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_sorted['possession_id'] = sequences_sorted['match_id'].astype(str) + sequences_sorted['possession'].astype(str)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['xg'] = sequences_filtered.groupby('possession_id')['shot_statsbomb_xg'].transform(lambda group: group.fillna(method='ffill').fillna(method='bfill'))
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sequences_filtered['xg'] = sequences_filtered.groupby('possession_id')['shot_statsbomb_xg'].transform(lambda group: group.fillna(method='ffill').fillna(method='bfill'))
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:69: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['end_location'] = sequences_filtered['location'].shift(-1)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sequences_filtered['end_location'] = sequences_filtered['location'].shift(-1)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered["start_x"] = sequences_filtered["location"].str[0]
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:76: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered["start_y"] = sequences_filtered["location"].str[1]
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:77: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered["end_x"] = sequences_filtered["end_location"].str[0]
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered["end_y"] = sequences_filtered["end_location"].str[1]
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:81: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['start_node_x'] = round(sequences_filtered['start_x'] / 20)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:82: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['start_node_y'] = round(sequences_filtered['start_y'] / 20)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['end_node_x'] = round(sequences_filtered['end_x'] / 20)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['end_node_y'] = round(sequences_filtered['end_y'] / 20)
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sequences_filtered_p2["start_node_y"] = 4 - sequences_filtered_p2["start_node_y"]
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sequences_filtered_p2["end_node_y"] = 4 - sequences_filtered_p2["end_node_y"]
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered["start_node"] = sequences_filtered["start_node_x"] + sequences_filtered["start_node_y"] / 10
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:95: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered["end_node"] = sequences_filtered["end_node_x"] + sequences_filtered["end_node_y"] / 10
# /Users/morten/Desktop/p5 kode/5-semester/Fodbold/Passing/helper_functions.py:102: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sequences_filtered['sequence'] = sequences_filtered.groupby('possession_id').cumcount(ascending=False) + 1

# %%
graph_list, graph_dict = create_graphs_dict(possesion, final_sequence)

# %%
for i, graph in enumerate(graph_list):
    print(f"\nGraph {i+1} with sequence attributes:")
    
    # Print Edge Attributes
    print("\nEdges and their sequence attributes:")
    for u, v, attr in graph.edges(data=True):
        print(f"Edge {u} -> {v}, Attributes: {attr}")
# Out:
# Graph 1 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.1 -> 4.2, Attributes: {'sequence': 50}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 37}
# Edge 4.1 -> 3.0, Attributes: {'sequence': 20}
# Edge 4.2 -> 3.3, Attributes: {'sequence': 49}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 42}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 21}
# Edge 4.2 -> 4.0, Attributes: {'sequence': 35}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 26}
# Edge 3.3 -> 4.2, Attributes: {'sequence': 43}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 3}
# Edge 4.3 -> 3.2, Attributes: {'sequence': 45}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 41}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 39}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 25}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 4}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 2}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 27}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 29}
# Edge 5.4 -> 4.3, Attributes: {'sequence': 40}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 11}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 36}
# Edge 5.2 -> 6.0, Attributes: {'sequence': 1}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 34}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 33}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 28}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 16}
# Edge 3.1 -> 2.2, Attributes: {'sequence': 14}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 31}
# Edge 3.0 -> 2.0, Attributes: {'sequence': 19}
# Edge 4.4 -> 6.3, Attributes: {'sequence': 24}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 23}
# Edge 2.0 -> 2.1, Attributes: {'sequence': 18}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 15}
# Edge 2.2 -> 6.4, Attributes: {'sequence': 13}
# Edge 6.4 -> 5.4, Attributes: {'sequence': 12}
#
# Graph 2 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.4 -> 3.3, Attributes: {'sequence': 9}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 8}
# Edge 3.3 -> 3.4, Attributes: {'sequence': 3}
# Edge 3.2 -> 4.0, Attributes: {'sequence': 7}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 4}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 5}
# Edge 3.4 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 3 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.2 -> 2.1, Attributes: {'sequence': 12}
# Edge 2.1 -> 2.0, Attributes: {'sequence': 11}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 5}
# Edge 2.0 -> 1.1, Attributes: {'sequence': 10}
# Edge 1.1 -> 1.2, Attributes: {'sequence': 9}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 6}
# Edge 1.2 -> 1.3, Attributes: {'sequence': 8}
# Edge 1.3 -> 1.1, Attributes: {'sequence': 7}
# Edge 3.1 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 3}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 6.3 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 4 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.4 -> 5.3, Attributes: {'sequence': 17}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 16}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 5.2 -> 4.1, Attributes: {'sequence': 15}
# Edge 5.2 -> 2.3, Attributes: {'sequence': 13}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 14}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 12}
# Edge 3.3 -> 4.2, Attributes: {'sequence': 11}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 9}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.2 -> 3.3, Attributes: {'sequence': 10}
# Edge 4.4 -> 1.3, Attributes: {'sequence': 8}
# Edge 1.3 -> 2.1, Attributes: {'sequence': 7}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 3.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 3}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 5 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.0 -> 2.1, Attributes: {'sequence': 11}
# Edge 2.0 -> 3.1, Attributes: {'sequence': 7}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 9}
# Edge 3.1 -> 3.3, Attributes: {'sequence': 6}
# Edge 3.2 -> 2.0, Attributes: {'sequence': 8}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 4}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 3}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 6 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.3 -> 2.2, Attributes: {'sequence': 17}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 16}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 13}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 15}
# Edge 3.1 -> 2.2, Attributes: {'sequence': 14}
# Edge 3.2 -> 5.2, Attributes: {'sequence': 12}
# Edge 5.2 -> 4.3, Attributes: {'sequence': 11}
# Edge 5.2 -> 5.4, Attributes: {'sequence': 5}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 10}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 8}
# Edge 4.3 -> 6.3, Attributes: {'sequence': 1}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 9}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 7}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 6}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.4 -> 4.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 3}
#
# Graph 7 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.4 -> 3.4, Attributes: {'sequence': 12}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 11}
# Edge 3.3 -> 2.2, Attributes: {'sequence': 10}
# Edge 3.3 -> 4.1, Attributes: {'sequence': 7}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 9}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 8}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 2}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 3}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 8 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.2 -> 3.0, Attributes: {'sequence': 7}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 5}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 4}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 2}
# Edge 6.1 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 9 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.4 -> 4.4, Attributes: {'sequence': 18}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 14}
# Edge 4.4 -> 3.4, Attributes: {'sequence': 17}
# Edge 3.3 -> 3.4, Attributes: {'sequence': 15}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 13}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 12}
# Edge 4.3 -> 1.4, Attributes: {'sequence': 10}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 11}
# Edge 1.4 -> 1.2, Attributes: {'sequence': 9}
# Edge 1.2 -> 2.2, Attributes: {'sequence': 8}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 7}
# Edge 2.1 -> 3.2, Attributes: {'sequence': 6}
# Edge 3.2 -> 4.0, Attributes: {'sequence': 5}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 4}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 3}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 2}
# Edge 5.2 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 10 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.3 -> 3.2, Attributes: {'sequence': 22}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 23}
# Edge 3.2 -> 2.1, Attributes: {'sequence': 21}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 16}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 20}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 19}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 17}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 15}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 18}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 14}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 1}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 13}
# Edge 4.2 -> 5.3, Attributes: {'sequence': 7}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 2}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 12}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 5}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 3}
# Edge 4.4 -> 6.3, Attributes: {'sequence': 11}
# Edge 6.3 -> 5.4, Attributes: {'sequence': 10}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 9}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 8}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 6}
# Edge 5.2 -> 4.3, Attributes: {'sequence': 4}
#
# Graph 11 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.4 -> 3.3, Attributes: {'sequence': 17}
# Edge 3.3 -> 3.4, Attributes: {'sequence': 16}
# Edge 3.3 -> 2.2, Attributes: {'sequence': 14}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 15}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 13}
# Edge 2.1 -> 3.0, Attributes: {'sequence': 12}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 11}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 8}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 6}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 9}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 7}
# Edge 4.1 -> 6.0, Attributes: {'sequence': 5}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 1}
# Edge 6.0 -> 5.0, Attributes: {'sequence': 4}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 2}
#
# Graph 12 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.1 -> 5.1, Attributes: {'sequence': 9}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 5}
# Edge 5.1 -> 4.0, Attributes: {'sequence': 8}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 7}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 6}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 3}
# Edge 4.3 -> 6.3, Attributes: {'sequence': 1}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 2}
#
# Graph 13 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.3 -> 1.4, Attributes: {'sequence': 18}
# Edge 2.3 -> 2.1, Attributes: {'sequence': 9}
# Edge 1.4 -> 0.3, Attributes: {'sequence': 17}
# Edge 0.3 -> 1.2, Attributes: {'sequence': 16}
# Edge 1.2 -> 1.0, Attributes: {'sequence': 15}
# Edge 1.0 -> 1.1, Attributes: {'sequence': 14}
# Edge 1.1 -> 0.2, Attributes: {'sequence': 13}
# Edge 0.2 -> 1.3, Attributes: {'sequence': 12}
# Edge 1.3 -> 2.2, Attributes: {'sequence': 11}
# Edge 2.2 -> 2.3, Attributes: {'sequence': 10}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 8}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 7}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 6}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 2}
# Edge 4.0 -> 5.0, Attributes: {'sequence': 5}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 4}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 3}
# Edge 4.2 -> 5.3, Attributes: {'sequence': 1}
#
# Graph 14 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 5.4 -> 4.3, Attributes: {'sequence': 21}
# Edge 4.3 -> 3.2, Attributes: {'sequence': 20}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 17}
# Edge 4.2 -> 3.2, Attributes: {'sequence': 18}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 16}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 9}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 15}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 3}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 14}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 10}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 8}
# Edge 5.0 -> 4.1, Attributes: {'sequence': 13}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 2}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 6}
# Edge 6.1 -> 5.1, Attributes: {'sequence': 4}
# Edge 6.2 -> 6.1, Attributes: {'sequence': 5}
# Edge 5.3 -> 5.0, Attributes: {'sequence': 1}
#
# Graph 15 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.0 -> 3.1, Attributes: {'sequence': 21}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 20}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 18}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 16}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 19}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 17}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 15}
# Edge 2.2 -> 3.3, Attributes: {'sequence': 14}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 6}
# Edge 3.3 -> 5.3, Attributes: {'sequence': 11}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 7}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.3 -> 4.4, Attributes: {'sequence': 10}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 8}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 9}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 1}
#
# Graph 16 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.0 -> 4.0, Attributes: {'sequence': 10}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 9}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 8}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 1}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 7}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 2}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 4}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 5}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 3}
#
# Graph 17 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.0 -> 3.0, Attributes: {'sequence': 13}
# Edge 3.0 -> 2.0, Attributes: {'sequence': 12}
# Edge 2.0 -> 2.1, Attributes: {'sequence': 11}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 10}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 9}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 8}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 6}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 7}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 5}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 4}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.2 -> 6.2, Attributes: {'sequence': 2}
#
# Graph 18 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 1.2, Attributes: {'sequence': 23}
# Edge 0.2 -> 1.0, Attributes: {'sequence': 15}
# Edge 1.2 -> 1.3, Attributes: {'sequence': 22}
# Edge 1.3 -> 2.3, Attributes: {'sequence': 21}
# Edge 2.3 -> 4.2, Attributes: {'sequence': 20}
# Edge 4.2 -> 2.2, Attributes: {'sequence': 19}
# Edge 2.2 -> 1.0, Attributes: {'sequence': 18}
# Edge 2.2 -> 3.3, Attributes: {'sequence': 6}
# Edge 1.0 -> 1.1, Attributes: {'sequence': 9}
# Edge 1.1 -> 0.2, Attributes: {'sequence': 16}
# Edge 1.1 -> 1.0, Attributes: {'sequence': 13}
# Edge 1.1 -> 0.0, Attributes: {'sequence': 11}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 8}
# Edge 0.0 -> 1.0, Attributes: {'sequence': 10}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 7}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 6.3, Attributes: {'sequence': 4}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 19 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.1 -> 3.1, Attributes: {'sequence': 16}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 15}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 13}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 7}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 14}
# Edge 3.0 -> 4.0, Attributes: {'sequence': 12}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 8}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 11}
# Edge 4.0 -> 3.0, Attributes: {'sequence': 9}
# Edge 4.0 -> 5.0, Attributes: {'sequence': 6}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 5}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 4}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 2}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 3}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 20 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.3 -> 3.2, Attributes: {'sequence': 17}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 13}
# Edge 3.2 -> 1.2, Attributes: {'sequence': 16}
# Edge 1.2 -> 2.2, Attributes: {'sequence': 15}
# Edge 2.2 -> 2.3, Attributes: {'sequence': 14}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 12}
# Edge 2.1 -> 1.1, Attributes: {'sequence': 11}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 9}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 8}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 6}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 7}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 5}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 4}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 3}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 1}
#
# Graph 21 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 3.1, Attributes: {'sequence': 9}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 5}
# Edge 3.1 -> 2.0, Attributes: {'sequence': 8}
# Edge 3.1 -> 4.2, Attributes: {'sequence': 3}
# Edge 2.0 -> 1.1, Attributes: {'sequence': 7}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 6}
# Edge 2.2 -> 3.1, Attributes: {'sequence': 4}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 1}
#
# Graph 22 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.2 -> 1.1, Attributes: {'sequence': 7}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 6}
# Edge 2.1 -> 3.2, Attributes: {'sequence': 5}
# Edge 3.2 -> 2.2, Attributes: {'sequence': 4}
# Edge 2.2 -> 3.3, Attributes: {'sequence': 3}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 2}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 23 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.1 -> 4.4, Attributes: {'sequence': 30}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 15}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 29}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 11}
# Edge 4.4 -> 3.4, Attributes: {'sequence': 1}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 21}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 23}
# Edge 5.3 -> 2.0, Attributes: {'sequence': 18}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 27}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 25}
# Edge 4.2 -> 5.4, Attributes: {'sequence': 20}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 26}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 22}
# Edge 4.3 -> 4.1, Attributes: {'sequence': 10}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 2}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 19}
# Edge 2.0 -> 3.0, Attributes: {'sequence': 17}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 16}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 14}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 9}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 6}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 13}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 12}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 3}
# Edge 5.0 -> 4.0, Attributes: {'sequence': 8}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 7}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 4}
#
# Graph 24 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.4 -> 3.3, Attributes: {'sequence': 11}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 10}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 8}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 9}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 3}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 6}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 4}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 2}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 5}
# Edge 5.4 -> 6.3, Attributes: {'sequence': 1}
#
# Graph 25 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 1.2, Attributes: {'sequence': 54}
# Edge 1.2 -> 1.1, Attributes: {'sequence': 53}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 52}
# Edge 2.1 -> 2.0, Attributes: {'sequence': 51}
# Edge 2.1 -> 3.3, Attributes: {'sequence': 49}
# Edge 2.0 -> 2.1, Attributes: {'sequence': 50}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 48}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 23}
# Edge 4.4 -> 3.3, Attributes: {'sequence': 24}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 37}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 26}
# Edge 4.4 -> 4.2, Attributes: {'sequence': 13}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 5}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 45}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 34}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 28}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 22}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 44}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 18}
# Edge 4.1 -> 4.3, Attributes: {'sequence': 16}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 9}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 42}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 33}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 41}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 17}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 25}
# Edge 4.3 -> 3.4, Attributes: {'sequence': 31}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 15}
# Edge 5.4 -> 2.2, Attributes: {'sequence': 36}
# Edge 5.4 -> 4.4, Attributes: {'sequence': 14}
# Edge 5.4 -> 6.3, Attributes: {'sequence': 4}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 35}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 30}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 21}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 12}
# Edge 4.2 -> 4.4, Attributes: {'sequence': 6}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 8}
# Edge 5.2 -> 4.1, Attributes: {'sequence': 10}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 7}
# Edge 6.3 -> 6.2, Attributes: {'sequence': 3}
# Edge 6.3 -> 2.4, Attributes: {'sequence': 1}
# Edge 6.2 -> 6.3, Attributes: {'sequence': 2}
#
# Graph 26 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.0 -> 6.0, Attributes: {'sequence': 9}
# Edge 6.0 -> 5.2, Attributes: {'sequence': 8}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 7}
# Edge 5.1 -> 5.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 5}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 5.4 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 3}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 27 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.4 -> 6.2, Attributes: {'sequence': 8}
# Edge 6.2 -> 5.4, Attributes: {'sequence': 7}
# Edge 5.4 -> 4.2, Attributes: {'sequence': 6}
# Edge 4.2 -> 3.3, Attributes: {'sequence': 5}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 3}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 1}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 2}
#
# Graph 28 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.1 -> 2.3, Attributes: {'sequence': 14}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 13}
# Edge 3.3 -> 4.1, Attributes: {'sequence': 12}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 11}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 2}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 9}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 4}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 6}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 7}
# Edge 6.3 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 5}
#
# Graph 29 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.0 -> 4.1, Attributes: {'sequence': 16}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 20}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 18}
# Edge 4.1 -> 4.3, Attributes: {'sequence': 15}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 1}
# Edge 5.0 -> 4.0, Attributes: {'sequence': 17}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 14}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 5}
# Edge 5.4 -> 6.3, Attributes: {'sequence': 13}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 12}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 11}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 9}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 10}
# Edge 4.2 -> 3.3, Attributes: {'sequence': 8}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 7}
# Edge 3.3 -> 2.2, Attributes: {'sequence': 4}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 6}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 3}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 2}
#
# Graph 30 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.2 -> 2.2, Attributes: {'sequence': 7}
# Edge 2.2 -> 4.4, Attributes: {'sequence': 6}
# Edge 4.4 -> 5.1, Attributes: {'sequence': 5}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 4}
# Edge 5.1 -> 6.3, Attributes: {'sequence': 2}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 3}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 31 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.3 -> 2.1, Attributes: {'sequence': 8}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 7}
# Edge 3.1 -> 0.2, Attributes: {'sequence': 6}
# Edge 0.2 -> 1.3, Attributes: {'sequence': 5}
# Edge 1.3 -> 3.4, Attributes: {'sequence': 4}
# Edge 3.4 -> 4.4, Attributes: {'sequence': 3}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 2}
# Edge 5.4 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 32 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.4 -> 6.2, Attributes: {'sequence': 14}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 13}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 11}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 9}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 12}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 10}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 8}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 2}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 5}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 3.2, Attributes: {'sequence': 1}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 4}
#
# Graph 33 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.2 -> 4.2, Attributes: {'sequence': 28}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 19}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 3}
# Edge 4.2 -> 3.3, Attributes: {'sequence': 27}
# Edge 4.2 -> 3.2, Attributes: {'sequence': 20}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 9}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 18}
# Edge 3.3 -> 4.2, Attributes: {'sequence': 21}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 23}
# Edge 4.4 -> 6.3, Attributes: {'sequence': 17}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 24}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 22}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 10}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 2}
# Edge 6.3 -> 6.2, Attributes: {'sequence': 16}
# Edge 6.3 -> 6.4, Attributes: {'sequence': 14}
# Edge 6.2 -> 6.3, Attributes: {'sequence': 15}
# Edge 6.4 -> 5.4, Attributes: {'sequence': 13}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 12}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 11}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 8}
# Edge 5.2 -> 4.1, Attributes: {'sequence': 6}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 7}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 5}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 4}
#
# Graph 34 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.0 -> 1.1, Attributes: {'sequence': 12}
# Edge 1.1 -> 2.0, Attributes: {'sequence': 11}
# Edge 2.0 -> 2.1, Attributes: {'sequence': 10}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 7}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 8}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 6}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 4}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 5}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 2}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 35 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.0 -> 6.2, Attributes: {'sequence': 10}
# Edge 6.2 -> 5.3, Attributes: {'sequence': 9}
# Edge 6.2 -> 5.2, Attributes: {'sequence': 2}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 4}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 5}
# Edge 5.4 -> 6.2, Attributes: {'sequence': 3}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 1}
#
# Graph 36 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.4 -> 4.3, Attributes: {'sequence': 24}
# Edge 4.4 -> 3.2, Attributes: {'sequence': 16}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 23}
# Edge 4.3 -> 6.1, Attributes: {'sequence': 9}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 3}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 1}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 22}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 17}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 15}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 18}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 10}
# Edge 3.1 -> 4.2, Attributes: {'sequence': 20}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 14}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 12}
# Edge 4.2 -> 3.2, Attributes: {'sequence': 19}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 7}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 13}
# Edge 2.1 -> 3.2, Attributes: {'sequence': 11}
# Edge 6.1 -> 4.2, Attributes: {'sequence': 8}
# Edge 5.2 -> 4.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 4}
# Edge 5.4 -> 4.3, Attributes: {'sequence': 2}
#
# Graph 37 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.4 -> 3.4, Attributes: {'sequence': 27}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 19}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 26}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 25}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 24}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 21}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 23}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 13}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 11}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 2}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 5}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 22}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 20}
# Edge 4.3 -> 5.1, Attributes: {'sequence': 15}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 18}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 16}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 17}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 4}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 6}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 1}
# Edge 5.0 -> 4.1, Attributes: {'sequence': 12}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 3}
#
# Graph 38 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.3 -> 3.2, Attributes: {'sequence': 25}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 24}
# Edge 3.1 -> 4.2, Attributes: {'sequence': 23}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 13}
# Edge 4.2 -> 3.1, Attributes: {'sequence': 22}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 14}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 18}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 9}
# Edge 4.0 -> 3.0, Attributes: {'sequence': 17}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 11}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 16}
# Edge 3.0 -> 4.0, Attributes: {'sequence': 12}
# Edge 5.0 -> 6.1, Attributes: {'sequence': 8}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 7}
# Edge 6.3 -> 5.4, Attributes: {'sequence': 6}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 3}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 4}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 2}
# Edge 5.2 -> 2.3, Attributes: {'sequence': 1}
#
# Graph 39 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.3 -> 2.4, Attributes: {'sequence': 10}
# Edge 2.3 -> 1.3, Attributes: {'sequence': 6}
# Edge 2.4 -> 0.3, Attributes: {'sequence': 9}
# Edge 0.3 -> 1.2, Attributes: {'sequence': 8}
# Edge 1.2 -> 2.3, Attributes: {'sequence': 7}
# Edge 1.2 -> 3.3, Attributes: {'sequence': 4}
# Edge 1.3 -> 1.2, Attributes: {'sequence': 5}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 3}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 2}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 40 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.3 -> 0.3, Attributes: {'sequence': 8}
# Edge 0.3 -> 3.3, Attributes: {'sequence': 7}
# Edge 3.3 -> 2.3, Attributes: {'sequence': 6}
# Edge 3.3 -> 4.2, Attributes: {'sequence': 2}
# Edge 2.3 -> 1.2, Attributes: {'sequence': 5}
# Edge 1.2 -> 0.2, Attributes: {'sequence': 4}
# Edge 0.2 -> 3.3, Attributes: {'sequence': 3}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 1}
#
# Graph 41 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.4 -> 0.4, Attributes: {'sequence': 9}
# Edge 1.4 -> 2.4, Attributes: {'sequence': 6}
# Edge 0.4 -> 0.3, Attributes: {'sequence': 8}
# Edge 0.3 -> 1.4, Attributes: {'sequence': 7}
# Edge 2.4 -> 2.3, Attributes: {'sequence': 5}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 4}
# Edge 2.2 -> 2.0, Attributes: {'sequence': 3}
# Edge 2.0 -> 3.1, Attributes: {'sequence': 2}
# Edge 3.1 -> 5.3, Attributes: {'sequence': 1}
#
# Graph 42 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.3 -> 1.4, Attributes: {'sequence': 16}
# Edge 1.4 -> 3.3, Attributes: {'sequence': 15}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 14}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 2}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 9}
# Edge 5.4 -> 6.2, Attributes: {'sequence': 12}
# Edge 5.4 -> 6.3, Attributes: {'sequence': 1}
# Edge 6.2 -> 5.1, Attributes: {'sequence': 11}
# Edge 5.1 -> 4.3, Attributes: {'sequence': 10}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 5}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 8}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 6}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 3}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 4}
#
# Graph 43 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.1 -> 2.1, Attributes: {'sequence': 38}
# Edge 2.1 -> 1.1, Attributes: {'sequence': 39}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 13}
# Edge 2.1 -> 3.2, Attributes: {'sequence': 20}
# Edge 2.1 -> 4.1, Attributes: {'sequence': 16}
# Edge 2.2 -> 2.4, Attributes: {'sequence': 36}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 17}
# Edge 2.2 -> 1.2, Attributes: {'sequence': 12}
# Edge 2.2 -> 2.3, Attributes: {'sequence': 10}
# Edge 2.4 -> 3.4, Attributes: {'sequence': 35}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 34}
# Edge 3.4 -> 4.4, Attributes: {'sequence': 27}
# Edge 3.4 -> 2.3, Attributes: {'sequence': 25}
# Edge 3.4 -> 4.3, Attributes: {'sequence': 8}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 33}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 29}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 23}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 30}
# Edge 3.2 -> 2.1, Attributes: {'sequence': 19}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 6}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 31}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 22}
# Edge 4.3 -> 3.4, Attributes: {'sequence': 28}
# Edge 4.3 -> 3.2, Attributes: {'sequence': 7}
# Edge 4.4 -> 3.4, Attributes: {'sequence': 26}
# Edge 2.3 -> 3.2, Attributes: {'sequence': 24}
# Edge 2.3 -> 3.4, Attributes: {'sequence': 9}
# Edge 3.0 -> 2.1, Attributes: {'sequence': 21}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 4}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 1}
# Edge 4.0 -> 2.1, Attributes: {'sequence': 14}
# Edge 4.0 -> 5.0, Attributes: {'sequence': 3}
# Edge 1.2 -> 2.2, Attributes: {'sequence': 11}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 5}
# Edge 5.0 -> 4.1, Attributes: {'sequence': 2}
#
# Graph 44 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 2.2, Attributes: {'sequence': 6}
# Edge 2.2 -> 3.1, Attributes: {'sequence': 5}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 4}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 3}
# Edge 3.2 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 45 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.0 -> 3.1, Attributes: {'sequence': 11}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 8}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 9}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 7}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 6}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 5}
# Edge 5.1 -> 5.0, Attributes: {'sequence': 4}
# Edge 5.1 -> 6.2, Attributes: {'sequence': 2}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.3 -> 2.1, Attributes: {'sequence': 1}
#
# Graph 46 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 1.2, Attributes: {'sequence': 24}
# Edge 1.2 -> 2.3, Attributes: {'sequence': 23}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 22}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 21}
# Edge 3.2 -> 4.0, Attributes: {'sequence': 20}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 14}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 16}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 18}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 15}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 17}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 13}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 8}
# Edge 5.2 -> 6.2, Attributes: {'sequence': 12}
# Edge 6.2 -> 4.3, Attributes: {'sequence': 11}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 9}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 7}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 5}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 6}
# Edge 4.2 -> 5.0, Attributes: {'sequence': 4}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 2}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 47 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.0 -> 3.0, Attributes: {'sequence': 13}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 11}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 4}
# Edge 3.0 -> 4.0, Attributes: {'sequence': 12}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 10}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 6}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 9}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 7}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 8}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 5}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 48 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 1.3, Attributes: {'sequence': 7}
# Edge 1.3 -> 2.2, Attributes: {'sequence': 6}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 5}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 4}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 3}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 2}
# Edge 4.2 -> 6.3, Attributes: {'sequence': 1}
#
# Graph 49 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.0 -> 2.1, Attributes: {'sequence': 12}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 11}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 8}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 9}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 7}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 6}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 5}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 3}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 2}
# Edge 6.3 -> 6.4, Attributes: {'sequence': 1}
#
# Graph 50 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.2 -> 1.1, Attributes: {'sequence': 12}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 11}
# Edge 2.1 -> 2.3, Attributes: {'sequence': 10}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 9}
# Edge 3.3 -> 2.2, Attributes: {'sequence': 8}
# Edge 3.3 -> 5.4, Attributes: {'sequence': 3}
# Edge 2.2 -> 3.0, Attributes: {'sequence': 7}
# Edge 2.2 -> 3.3, Attributes: {'sequence': 4}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 2.2, Attributes: {'sequence': 5}
# Edge 5.4 -> 6.3, Attributes: {'sequence': 2}
# Edge 6.3 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 51 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.2 -> 5.1, Attributes: {'sequence': 35}
# Edge 3.2 -> 4.4, Attributes: {'sequence': 4}
# Edge 5.1 -> 6.2, Attributes: {'sequence': 34}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 32}
# Edge 6.2 -> 5.2, Attributes: {'sequence': 33}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 31}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 22}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 16}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 6}
# Edge 4.4 -> 3.3, Attributes: {'sequence': 27}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 3}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 26}
# Edge 3.3 -> 3.1, Attributes: {'sequence': 24}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 25}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 23}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 12}
# Edge 5.0 -> 4.0, Attributes: {'sequence': 8}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 7}
# Edge 4.0 -> 3.0, Attributes: {'sequence': 18}
# Edge 4.0 -> 5.0, Attributes: {'sequence': 9}
# Edge 4.0 -> 3.1, Attributes: {'sequence': 13}
# Edge 3.0 -> 4.1, Attributes: {'sequence': 17}
# Edge 4.2 -> 3.2, Attributes: {'sequence': 5}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 1.1, Attributes: {'sequence': 1}
#
# Graph 52 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.1 -> 2.1, Attributes: {'sequence': 13}
# Edge 1.1 -> 0.1, Attributes: {'sequence': 9}
# Edge 2.1 -> 2.0, Attributes: {'sequence': 12}
# Edge 2.1 -> 2.3, Attributes: {'sequence': 6}
# Edge 2.0 -> 1.0, Attributes: {'sequence': 11}
# Edge 1.0 -> 1.1, Attributes: {'sequence': 10}
# Edge 0.1 -> 3.1, Attributes: {'sequence': 8}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 7}
# Edge 2.3 -> 5.3, Attributes: {'sequence': 5}
# Edge 5.3 -> 5.1, Attributes: {'sequence': 4}
# Edge 5.3 -> 6.4, Attributes: {'sequence': 1}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 3}
# Edge 6.4 -> 5.3, Attributes: {'sequence': 2}
#
# Graph 53 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.1 -> 1.2, Attributes: {'sequence': 17}
# Edge 1.2 -> 2.3, Attributes: {'sequence': 16}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 15}
# Edge 3.3 -> 2.2, Attributes: {'sequence': 14}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 6}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 4}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 9}
# Edge 2.1 -> 3.0, Attributes: {'sequence': 12}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 10}
# Edge 2.1 -> 3.4, Attributes: {'sequence': 8}
# Edge 3.0 -> 2.1, Attributes: {'sequence': 11}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 7}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 3}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 0.2, Attributes: {'sequence': 1}
#
# Graph 54 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.3 -> 2.1, Attributes: {'sequence': 9}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 3}
# Edge 3.1 -> 2.0, Attributes: {'sequence': 7}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 4}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 2}
# Edge 2.0 -> 3.0, Attributes: {'sequence': 6}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 5}
# Edge 4.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 55 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 2.2, Attributes: {'sequence': 27}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 16}
# Edge 2.2 -> 2.3, Attributes: {'sequence': 26}
# Edge 2.2 -> 3.1, Attributes: {'sequence': 23}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 25}
# Edge 3.3 -> 2.2, Attributes: {'sequence': 24}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 22}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 20}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 15}
# Edge 3.0 -> 3.1, Attributes: {'sequence': 21}
# Edge 4.0 -> 1.0, Attributes: {'sequence': 19}
# Edge 1.0 -> 2.0, Attributes: {'sequence': 18}
# Edge 2.0 -> 2.1, Attributes: {'sequence': 17}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 14}
# Edge 4.2 -> 5.3, Attributes: {'sequence': 13}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 8}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 10}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 6}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 7}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 9}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 5}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.2 -> 6.2, Attributes: {'sequence': 2}
# Edge 6.2 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 56 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.2 -> 0.2, Attributes: {'sequence': 7}
# Edge 1.2 -> 1.1, Attributes: {'sequence': 5}
# Edge 0.2 -> 1.2, Attributes: {'sequence': 6}
# Edge 1.1 -> 2.2, Attributes: {'sequence': 4}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 3}
# Edge 3.2 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 57 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.3 -> 1.2, Attributes: {'sequence': 21}
# Edge 1.2 -> 3.1, Attributes: {'sequence': 20}
# Edge 1.2 -> 2.3, Attributes: {'sequence': 17}
# Edge 3.1 -> 1.1, Attributes: {'sequence': 19}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 5}
# Edge 1.1 -> 1.2, Attributes: {'sequence': 18}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 16}
# Edge 2.2 -> 3.1, Attributes: {'sequence': 15}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 2}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 4}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 9}
# Edge 5.0 -> 2.2, Attributes: {'sequence': 1}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 11}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 8}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 7}
# Edge 4.2 -> 3.1, Attributes: {'sequence': 6}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 3}
#
# Graph 58 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.2 -> 2.3, Attributes: {'sequence': 15}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 14}
# Edge 2.3 -> 3.2, Attributes: {'sequence': 11}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 13}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 9}
# Edge 3.2 -> 2.3, Attributes: {'sequence': 12}
# Edge 3.2 -> 3.3, Attributes: {'sequence': 10}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 8}
# Edge 4.3 -> 1.3, Attributes: {'sequence': 1}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 7}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 2}
# Edge 5.4 -> 6.4, Attributes: {'sequence': 6}
# Edge 6.4 -> 6.3, Attributes: {'sequence': 5}
# Edge 6.3 -> 6.2, Attributes: {'sequence': 4}
# Edge 6.3 -> 4.4, Attributes: {'sequence': 3}
#
# Graph 59 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.3 -> 2.3, Attributes: {'sequence': 7}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 6}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 5}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 4}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 3}
# Edge 4.0 -> 5.0, Attributes: {'sequence': 2}
# Edge 5.0 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 60 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.1 -> 0.0, Attributes: {'sequence': 12}
# Edge 0.1 -> 1.2, Attributes: {'sequence': 10}
# Edge 0.0 -> 0.1, Attributes: {'sequence': 11}
# Edge 1.2 -> 1.3, Attributes: {'sequence': 9}
# Edge 1.3 -> 1.4, Attributes: {'sequence': 8}
# Edge 1.4 -> 0.3, Attributes: {'sequence': 7}
# Edge 0.3 -> 3.3, Attributes: {'sequence': 6}
# Edge 3.3 -> 2.3, Attributes: {'sequence': 5}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 3}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 4}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 61 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.0 -> 5.2, Attributes: {'sequence': 13}
# Edge 5.2 -> 4.1, Attributes: {'sequence': 12}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 5}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 10}
# Edge 3.1 -> 2.2, Attributes: {'sequence': 8}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 4}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 9}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 6}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 7}
# Edge 2.1 -> 4.0, Attributes: {'sequence': 3}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 62 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.3 -> 3.2, Attributes: {'sequence': 4}
# Edge 2.3 -> 1.4, Attributes: {'sequence': 9}
# Edge 2.3 -> 1.3, Attributes: {'sequence': 7}
# Edge 3.2 -> 3.0, Attributes: {'sequence': 12}
# Edge 3.2 -> 2.3, Attributes: {'sequence': 5}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 3}
# Edge 3.0 -> 2.1, Attributes: {'sequence': 11}
# Edge 2.1 -> 2.3, Attributes: {'sequence': 10}
# Edge 1.4 -> 2.3, Attributes: {'sequence': 8}
# Edge 1.3 -> 3.2, Attributes: {'sequence': 6}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 2}
# Edge 5.2 -> 6.3, Attributes: {'sequence': 1}
#
# Graph 63 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 1.2, Attributes: {'sequence': 12}
# Edge 1.2 -> 2.1, Attributes: {'sequence': 11}
# Edge 2.1 -> 3.2, Attributes: {'sequence': 5}
# Edge 3.2 -> 2.2, Attributes: {'sequence': 7}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 4}
# Edge 2.2 -> 3.2, Attributes: {'sequence': 8}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 6}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 64 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.4 -> 5.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 5}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 4}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 2}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 65 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.0 -> 6.2, Attributes: {'sequence': 11}
# Edge 6.2 -> 5.4, Attributes: {'sequence': 10}
# Edge 5.4 -> 6.4, Attributes: {'sequence': 9}
# Edge 6.4 -> 4.3, Attributes: {'sequence': 8}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 7}
# Edge 4.2 -> 4.0, Attributes: {'sequence': 4}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 3}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 2}
# Edge 5.0 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 66 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.0 -> 1.1, Attributes: {'sequence': 19}
# Edge 1.1 -> 1.2, Attributes: {'sequence': 18}
# Edge 1.2 -> 2.3, Attributes: {'sequence': 17}
# Edge 2.3 -> 3.4, Attributes: {'sequence': 9}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 13}
# Edge 2.3 -> 0.2, Attributes: {'sequence': 11}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 8}
# Edge 3.4 -> 4.4, Attributes: {'sequence': 6}
# ...
# Edge 3.1 -> 2.2, Attributes: {'sequence': 11}
# Edge 3.1 -> 4.2, Attributes: {'sequence': 3}
# Edge 2.2 -> 3.3, Attributes: {'sequence': 10}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 9}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 8}
# Edge 4.2 -> 5.1, Attributes: {'sequence': 7}
# Edge 4.2 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 6}
# Edge 5.1 -> 3.1, Attributes: {'sequence': 4}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 5}
# Edge 5.3 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 87 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 1.2, Attributes: {'sequence': 11}
# Edge 1.2 -> 1.1, Attributes: {'sequence': 10}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 9}
# Edge 2.1 -> 1.0, Attributes: {'sequence': 8}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 5}
# Edge 1.0 -> 3.1, Attributes: {'sequence': 7}
# Edge 3.1 -> 2.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 3.3, Attributes: {'sequence': 4}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 3}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 1}
#
# Graph 88 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.3 -> 2.3, Attributes: {'sequence': 26}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 20}
# Edge 2.3 -> 2.4, Attributes: {'sequence': 25}
# Edge 2.4 -> 3.4, Attributes: {'sequence': 24}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 23}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 21}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 19}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 13}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 18}
# Edge 4.4 -> 3.2, Attributes: {'sequence': 11}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 16}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.4 -> 4.3, Attributes: {'sequence': 14}
# Edge 5.4 -> 4.4, Attributes: {'sequence': 12}
# Edge 3.2 -> 2.2, Attributes: {'sequence': 10}
# Edge 2.2 -> 3.1, Attributes: {'sequence': 9}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 8}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 7}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 6}
# Edge 5.2 -> 4.3, Attributes: {'sequence': 5}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 1}
#
# Graph 89 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.3 -> 2.2, Attributes: {'sequence': 18}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 15}
# Edge 2.2 -> 2.3, Attributes: {'sequence': 17}
# Edge 2.3 -> 3.3, Attributes: {'sequence': 16}
# Edge 4.3 -> 5.2, Attributes: {'sequence': 14}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 3}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 1}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 13}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 12}
# Edge 5.4 -> 3.2, Attributes: {'sequence': 11}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 10}
# Edge 3.1 -> 3.0, Attributes: {'sequence': 9}
# Edge 3.0 -> 4.1, Attributes: {'sequence': 8}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 7}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 5}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 6}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 2}
#
# Graph 90 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 3.1, Attributes: {'sequence': 21}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 18}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 19}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 13}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 11}
# Edge 4.1 -> 5.0, Attributes: {'sequence': 3}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 12}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 10}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 9}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 6}
# Edge 4.3 -> 4.1, Attributes: {'sequence': 4}
# Edge 5.4 -> 4.4, Attributes: {'sequence': 8}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 5}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 91 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.3 -> 3.2, Attributes: {'sequence': 12}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 11}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 10}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 8}
# Edge 4.1 -> 5.2, Attributes: {'sequence': 5}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 9}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 7}
# Edge 5.2 -> 4.1, Attributes: {'sequence': 6}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 3}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 2}
#
# Graph 92 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.4 -> 6.2, Attributes: {'sequence': 36}
# Edge 6.2 -> 5.0, Attributes: {'sequence': 35}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 34}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 33}
# Edge 4.1 -> 5.4, Attributes: {'sequence': 32}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 6}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 31}
# Edge 5.4 -> 4.4, Attributes: {'sequence': 12}
# Edge 5.4 -> 4.3, Attributes: {'sequence': 19}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 30}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 3}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 11}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 25}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 10}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 13}
# Edge 4.3 -> 3.2, Attributes: {'sequence': 8}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 4}
# Edge 4.2 -> 4.4, Attributes: {'sequence': 26}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 5}
# Edge 3.2 -> 4.1, Attributes: {'sequence': 7}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 2}
#
# Graph 93 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.0 -> 0.0, Attributes: {'sequence': 9}
# Edge 1.0 -> 1.2, Attributes: {'sequence': 7}
# Edge 0.0 -> 1.0, Attributes: {'sequence': 8}
# Edge 1.2 -> 3.3, Attributes: {'sequence': 6}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 5}
# Edge 4.4 -> 4.2, Attributes: {'sequence': 4}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 3}
# Edge 4.3 -> 4.1, Attributes: {'sequence': 2}
# Edge 4.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 94 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 5}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 4}
# Edge 5.1 -> 5.3, Attributes: {'sequence': 3}
# Edge 5.3 -> 6.2, Attributes: {'sequence': 2}
# Edge 6.2 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 95 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 3.2, Attributes: {'sequence': 18}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 17}
# Edge 4.2 -> 5.2, Attributes: {'sequence': 16}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 14}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 15}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 3}
# Edge 4.1 -> 4.0, Attributes: {'sequence': 13}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 12}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 6}
# Edge 5.1 -> 6.2, Attributes: {'sequence': 2}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 4}
# Edge 6.1 -> 5.1, Attributes: {'sequence': 5}
# Edge 6.2 -> 5.2, Attributes: {'sequence': 8}
# Edge 6.2 -> 4.4, Attributes: {'sequence': 1}
#
# Graph 96 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.4 -> 4.3, Attributes: {'sequence': 6}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 5}
# Edge 4.3 -> 6.2, Attributes: {'sequence': 2}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 3}
# Edge 6.2 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 97 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 5.4 -> 4.4, Attributes: {'sequence': 7}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 5}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 4}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 3}
# Edge 6.3 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 98 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 5.0 -> 4.0, Attributes: {'sequence': 11}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 10}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 4}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 9}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 1}
# Edge 3.1 -> 4.3, Attributes: {'sequence': 8}
# Edge 4.3 -> 3.2, Attributes: {'sequence': 7}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 6}
# Edge 4.2 -> 4.0, Attributes: {'sequence': 5}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 3}
# Edge 6.1 -> 5.2, Attributes: {'sequence': 2}
#
# Graph 99 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.2 -> 4.2, Attributes: {'sequence': 20}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 19}
# Edge 4.3 -> 3.3, Attributes: {'sequence': 18}
# Edge 3.3 -> 3.4, Attributes: {'sequence': 17}
# Edge 3.4 -> 4.4, Attributes: {'sequence': 16}
# Edge 4.4 -> 5.4, Attributes: {'sequence': 15}
# Edge 5.4 -> 6.4, Attributes: {'sequence': 3}
# Edge 6.4 -> 6.2, Attributes: {'sequence': 2}
# Edge 6.2 -> 2.2, Attributes: {'sequence': 1}
# Edge 6.0 -> 6.1, Attributes: {'sequence': 12}
# Edge 6.1 -> 5.1, Attributes: {'sequence': 11}
# Edge 5.1 -> 3.1, Attributes: {'sequence': 10}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 9}
# Edge 4.0 -> 5.0, Attributes: {'sequence': 8}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 7}
# Edge 4.1 -> 5.3, Attributes: {'sequence': 5}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 4}
#
# Graph 100 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.2 -> 2.1, Attributes: {'sequence': 15}
# Edge 2.1 -> 3.0, Attributes: {'sequence': 14}
# Edge 3.0 -> 4.0, Attributes: {'sequence': 13}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 12}
# Edge 4.1 -> 3.2, Attributes: {'sequence': 11}
# Edge 3.2 -> 4.3, Attributes: {'sequence': 10}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 9}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 5}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 8}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 4}
# Edge 6.3 -> 4.3, Attributes: {'sequence': 6}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 3}
# Edge 5.2 -> 4.2, Attributes: {'sequence': 2}
# Edge 4.2 -> 5.3, Attributes: {'sequence': 1}
#
# Graph 101 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 5.4 -> 4.3, Attributes: {'sequence': 7}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 4.2, Attributes: {'sequence': 5}
# Edge 4.2 -> 4.1, Attributes: {'sequence': 4}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 6.1, Attributes: {'sequence': 2}
# Edge 6.1 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 102 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 0.3, Attributes: {'sequence': 31}
# Edge 0.3 -> 1.3, Attributes: {'sequence': 30}
# Edge 1.3 -> 3.3, Attributes: {'sequence': 29}
# Edge 3.3 -> 2.3, Attributes: {'sequence': 4}
# Edge 3.3 -> 4.3, Attributes: {'sequence': 17}
# Edge 2.3 -> 4.4, Attributes: {'sequence': 27}
# Edge 2.3 -> 2.2, Attributes: {'sequence': 3}
# Edge 4.4 -> 5.3, Attributes: {'sequence': 26}
# Edge 4.4 -> 4.3, Attributes: {'sequence': 8}
# Edge 4.4 -> 3.4, Attributes: {'sequence': 6}
# Edge 5.3 -> 3.0, Attributes: {'sequence': 25}
# Edge 3.0 -> 2.0, Attributes: {'sequence': 24}
# Edge 2.0 -> 2.1, Attributes: {'sequence': 23}
# Edge 2.1 -> 3.1, Attributes: {'sequence': 22}
# Edge 2.1 -> 1.2, Attributes: {'sequence': 1}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 21}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 20}
# Edge 5.1 -> 6.3, Attributes: {'sequence': 19}
# Edge 6.3 -> 3.3, Attributes: {'sequence': 18}
# Edge 4.3 -> 3.2, Attributes: {'sequence': 16}
# Edge 4.3 -> 4.4, Attributes: {'sequence': 7}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 11}
# Edge 4.2 -> 3.2, Attributes: {'sequence': 12}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 10}
# Edge 3.4 -> 3.3, Attributes: {'sequence': 5}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 2}
#
# Graph 103 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 1.2 -> 1.3, Attributes: {'sequence': 10}
# Edge 1.3 -> 1.4, Attributes: {'sequence': 9}
# Edge 1.3 -> 2.0, Attributes: {'sequence': 7}
# Edge 1.4 -> 1.3, Attributes: {'sequence': 8}
# Edge 2.0 -> 5.1, Attributes: {'sequence': 6}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 1}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 2}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 3}
#
# Graph 104 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.0 -> 5.0, Attributes: {'sequence': 6}
# Edge 5.0 -> 4.0, Attributes: {'sequence': 5}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 4}
# Edge 4.1 -> 4.3, Attributes: {'sequence': 3}
# Edge 4.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 1}
#
# Graph 105 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 2.1 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.1 -> 5.0, Attributes: {'sequence': 5}
# Edge 5.0 -> 6.1, Attributes: {'sequence': 4}
# Edge 6.1 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 2}
# Edge 5.2 -> 6.2, Attributes: {'sequence': 1}
#
# Graph 106 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 3.2, Attributes: {'sequence': 17}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 11}
# Edge 3.1 -> 3.3, Attributes: {'sequence': 15}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 10}
# Edge 3.3 -> 4.4, Attributes: {'sequence': 14}
# Edge 3.3 -> 3.2, Attributes: {'sequence': 12}
# Edge 4.4 -> 3.3, Attributes: {'sequence': 13}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 9}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 8}
# Edge 4.3 -> 5.4, Attributes: {'sequence': 7}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 6}
# Edge 5.3 -> 6.3, Attributes: {'sequence': 5}
# Edge 6.3 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.2 -> 5.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 5.0, Attributes: {'sequence': 2}
# Edge 5.0 -> 6.0, Attributes: {'sequence': 1}
#
# Graph 107 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 6.0 -> 5.0, Attributes: {'sequence': 18}
# Edge 5.0 -> 4.1, Attributes: {'sequence': 17}
# Edge 4.1 -> 3.1, Attributes: {'sequence': 11}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 2}
# Edge 3.1 -> 4.0, Attributes: {'sequence': 15}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 12}
# Edge 3.1 -> 3.2, Attributes: {'sequence': 10}
# Edge 3.1 -> 5.1, Attributes: {'sequence': 8}
# Edge 4.0 -> 4.1, Attributes: {'sequence': 14}
# Edge 3.2 -> 3.1, Attributes: {'sequence': 9}
# Edge 5.1 -> 4.1, Attributes: {'sequence': 3}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 5}
# Edge 5.1 -> 3.3, Attributes: {'sequence': 1}
#
# Graph 108 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 3.3 -> 4.3, Attributes: {'sequence': 8}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 7}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 5}
# Edge 4.3 -> 6.3, Attributes: {'sequence': 2}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 3}
# Edge 4.2 -> 5.3, Attributes: {'sequence': 4}
# Edge 6.3 -> 5.2, Attributes: {'sequence': 1}
#
# Graph 109 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 0.2 -> 1.1, Attributes: {'sequence': 21}
# Edge 1.1 -> 2.1, Attributes: {'sequence': 20}
# Edge 2.1 -> 2.2, Attributes: {'sequence': 19}
# Edge 2.1 -> 4.0, Attributes: {'sequence': 17}
# Edge 2.2 -> 2.1, Attributes: {'sequence': 18}
# Edge 4.0 -> 5.1, Attributes: {'sequence': 16}
# Edge 5.1 -> 5.2, Attributes: {'sequence': 14}
# Edge 5.1 -> 5.0, Attributes: {'sequence': 3}
# Edge 5.1 -> 4.0, Attributes: {'sequence': 1}
# Edge 5.2 -> 5.3, Attributes: {'sequence': 13}
# Edge 5.3 -> 4.3, Attributes: {'sequence': 12}
# Edge 4.3 -> 4.2, Attributes: {'sequence': 9}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 10}
# Edge 4.2 -> 3.2, Attributes: {'sequence': 8}
# Edge 4.2 -> 3.1, Attributes: {'sequence': 6}
# Edge 3.2 -> 4.2, Attributes: {'sequence': 7}
# Edge 3.1 -> 4.1, Attributes: {'sequence': 5}
# Edge 4.1 -> 5.1, Attributes: {'sequence': 4}
# Edge 5.0 -> 5.1, Attributes: {'sequence': 2}
#
# Graph 110 with sequence attributes:
#
# Edges and their sequence attributes:
# Edge 4.0 -> 4.1, Attributes: {'sequence': 7}
# Edge 4.1 -> 4.2, Attributes: {'sequence': 6}
# Edge 4.2 -> 4.3, Attributes: {'sequence': 5}
# Edge 4.3 -> 5.3, Attributes: {'sequence': 4}
# Edge 5.3 -> 5.4, Attributes: {'sequence': 3}
# Edge 5.3 -> 5.2, Attributes: {'sequence': 1}
# Edge 5.4 -> 5.3, Attributes: {'sequence': 2}

# %%
possesion
# Out:
# array([  38952108,  389505258,  389505264,  389506724,  389506727,
#         389506743,  389506768,  389506780,  389506798,  389508612,
#         389508619,  389508646,  389508652,  389508681,  389510728,
#         389510735,  389510744,  389510749,  389510755,  389510763,
#         389512115,  389512147,  389512155,  389512157,  389512183,
#         389515810,  389515869,  389515886,  389518035,  389518219,
#         389518260,  389518267,  389518273,  389518279,  389521021,
#         389521039,  389521071,  389521090,  389521094,  389523228,
#         389523254,  389525030,  389525037,  389525049,  389526645,
#         389526666,  389528621,  389528666,  389528671,  389530214,
#         389530255,  389530258,  389530299,  389532050,  389534822,
#         389534872,  389534883,  389534895,  389534897, 3895052101,
#        3895052128, 3895067102, 3895067106, 3895067111, 3895067129,
#        3895086133, 3895107104, 3895107115, 3895121123, 3895139105,
#        3895139121, 3895158116, 3895180108, 3895180119, 3895180138,
#        3895180143, 3895180162, 3895180165, 3895182116, 3895182126,
#        3895182136, 3895182162, 3895210112, 3895210141, 3895210150,
#        3895210154, 3895232108, 3895232151, 3895250128, 3895266102,
#        3895266124, 3895266126, 3895266128, 3895286111, 3895286122,
#        3895286126, 3895286129, 3895286135, 3895286144, 3895286155,
#        3895286161, 3895302108, 3895302126, 3895320108, 3895320116,
#        3895348101, 3895348104, 3895348106, 3895348127, 3895348128])

# %%
plot = plot_graphs(graph_dict, 38952108)
