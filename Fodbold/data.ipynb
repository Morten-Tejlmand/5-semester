# %%
from statsbombpy import sb
import pandas as pd

# %%
events = sb.competitions()
events
# Out:
# c:\Users\nikka\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events = sb.competition_events(
    country="Germany",
    division= "1. Bundesliga",
    season="2023/2024",
    gender="male"
)
# Out:
# c:\Users\nikka\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events
# Out:
#        50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0        NaN                NaN                  NaN                     NaN
# 1        NaN                NaN                  NaN                     NaN
# 2        NaN                NaN                  NaN                     NaN
# 3        NaN                NaN                  NaN                     NaN
# 4        NaN                NaN                  NaN                     NaN
# ...      ...                ...                  ...                     ...
# 137760   NaN                NaN                  NaN                     NaN
# 137761   NaN                NaN                  NaN                     NaN
# 137762   NaN                NaN                  NaN                     NaN
# 137763   NaN                NaN                  NaN                     NaN
# 137764   NaN                NaN                  NaN                     NaN
#
# ...

# %%
print("Hello there")
