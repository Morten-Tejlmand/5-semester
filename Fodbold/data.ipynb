# %%
from statsbombpy import sb
import pandas as pd

# %%
events = sb.competitions()
events
# Out:
# c:\Users\nikka\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events = sb.competition_events(
    country="Spain",
    division= "La Liga",
    season="2020/2021",
    gender="male"
)

# %%
events
# Out:
#        50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0        NaN                NaN                  NaN                     NaN
# 1        NaN                NaN                  NaN                     NaN
# 2        NaN                NaN                  NaN                     NaN
# 3        NaN                NaN                  NaN                     NaN
# 4        NaN                NaN                  NaN                     NaN
# ...      ...                ...                  ...                     ...
# 139025   NaN                NaN                  NaN                     NaN
# 139026   NaN                NaN                  NaN                     NaN
# 139027   NaN                NaN                  NaN                     NaN
# 139028   NaN                NaN                  NaN                     NaN
# 139029   NaN                NaN                  NaN                     NaN
#
# ...
